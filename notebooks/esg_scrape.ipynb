# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# Creating a webdriver instance
driver = webdriver.Chrome("../chrome_driver/chromedriver.exe")
# This instance will be used to log into LinkedIn

# Opening linkedIn's login page
driver.get("https://www.sustainalytics.com/esg-rating")
time.sleep(1)

# waiting for the page to load


# entering username
tickers = driver.find_element(By.ID, "searchInput")

# Enter Your Email Address

tickers.send_keys("AA")
time.sleep(1)
tickers.send_keys("PL")
time.sleep(1)


driver.find_element(By.XPATH, "//a[@class='search-link js-fix-path']").click()
# In case of an error, try changing the
# XPath used here.

src = driver.page_source
# Out:
# C:\Users\nayan\AppData\Local\Temp\ipykernel_16124\1992888241.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("../chrome_driver/chromedriver.exe")
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File d:\Stock_Prediction_rel1.0\stockPred1.0\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
# ...

# %%
from bs4 import BeautifulSoup

# Load the HTML content
html_content = src

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Find the company name
company_name = soup.find('div', class_='company-name').h2.text.strip()

# Find the industry group
industry_group = soup.find('strong', class_='industry-group').text.strip()

# Find the country/region
country = soup.find('strong', class_='country').text.strip()

# Find the identifier
identifier = soup.find('strong', class_='identifier').text.strip()

# Find the company description
company_description = soup.find('div', class_='company-description-text').find('span').text.strip()


# Find the full-time employees
full_time_employees = soup.find('div', class_='company-description-details').strong.text.strip()

# Find the ESG risk rating
esg_risk_rating = soup.find('h3', text='ESG Risk Rating').find_next('span', class_='').text.strip()
esg_rating_assessment = soup.find('div', class_='risk-rating-assessment').span.text.strip()

# Find the industry group ranking
industry_group_ranking = soup.find('p', class_='intro-ranking-heading', text='Industry Group (1st = lowest risk)')
industry_group_position = industry_group_ranking.find_next('strong', class_='industry-group-position').text.strip()
industry_group_positions_total = industry_group_ranking.find_next('span', class_='industry-group-positions-total').text.strip()

# industry Format the ranking as desired
industry_group_ranking_formatted = f"{industry_group_position}/{industry_group_positions_total}"

# Find the universe ranking
universe_ranking = soup.find('p', class_='intro-ranking-heading', text='Universe')
universe_position = universe_ranking.find_next('strong', class_='universe-position').text.strip()
universe_positions_total = universe_ranking.find_next('span', class_='universe-positions-total').text.strip()
# universe Format the ranking as desired
universe_ranking_formatted = f"{universe_position}/{universe_positions_total}"

# Find the last update date
last_update_date = soup.find('div', class_='update-date').strong.text.strip()

# Print the scraped data
print('Company Name:', company_name)
print('Industry Group:', industry_group)
print('Country/Region:', country)
print('Identifier:', identifier)
print('Company Description:', company_description)
print('Full Time Employees:', full_time_employees)
print('ESG Risk Rating:', esg_risk_rating)
print('ESG Risk Rating Assessment:', esg_rating_assessment)
print('Industry Group Position:', industry_group_position)
print('Industry Group Positions Total:', industry_group_ranking_formatted)
print('Universe Position:', universe_position)
print('Universe Positions Total:', universe_ranking_formatted)
print('Last Update Date:', last_update_date)
# Out:
# Company Name: Apple, Inc.
# Industry Group: Technology Hardware
# Country/Region: United States of America
# Identifier: NAS:AAPL
# Company Description: Apple designs a wide variety of consumer electronic devices, including smartphones (iPhone), tablets (iPad), PCs (Mac), smartwatches (Apple Watch), and AirPods. The iPhone makes up most of Apple’s total revenue. In addition, Apple offers its customers a variety of services such as Apple Music, iCloud, Apple Care, Apple TV+, Apple Arcade, Apple Fitness, Apple Card, and Apple Pay, among others. Apple's products include internally developed software and semiconductors, and the firm is well known for its integration of hardware, software, semiconductors, and services. Apple's products are distributed online as well as through company-owned stores and third-party retailers. The company generates roughly 40% of its revenue from the Americas, with the remainder earned internationally.
# Full Time Employees: 164,000
# ...

# %%
soup
# Out:
# <html lang="en"><head> <meta charset="utf-8"/> <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/> <link href="/favicon.png?v=2.0" rel="shortcut icon" type="image/png"/> <title>
# 	Advance Auto Parts, Inc. ESG Risk Rating
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup


# Load the HTML content
html_content = src

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Find the company name
company_name = soup.find('div', class_='company-name').h2.text.strip()

# Find the industry group
industry_group = soup.find('strong', class_='industry-group').text.strip()

# Find the country/region
country = soup.find('strong', class_='country').text.strip()

# Find the identifier
identifier = soup.find('strong', class_='identifier').text.strip()

# Find the company description
company_description = soup.find('div', class_='company-description-text').find('span').text.strip()

# Find the full-time employees
full_time_employees = soup.find('div', class_='company-description-details').strong.text.strip()

# Find the ESG risk rating
esg_risk_rating = soup.find('h3', text='ESG Risk Rating').find_next('span', class_='').text.strip()
esg_rating_assessment = soup.find('div', class_='risk-rating-assessment').span.text.strip()

# Find the industry group ranking
industry_group_ranking = soup.find('p', class_='intro-ranking-heading', text='Industry Group (1st = lowest risk)')
industry_group_position = industry_group_ranking.find_next('strong', class_='industry-group-position').text.strip()
industry_group_positions_total = industry_group_ranking.find_next('span', class_='industry-group-positions-total').text.strip()
industry_group_ranking_formatted = f"{industry_group_position}/{industry_group_positions_total}"

# Find the universe ranking
universe_ranking = soup.find('p', class_='intro-ranking-heading', text='Universe')
universe_position = universe_ranking.find_next('strong', class_='universe-position').text.strip()
universe_positions_total = universe_ranking.find_next('span', class_='universe-positions-total').text.strip()
universe_ranking_formatted = f"{universe_position}/{universe_positions_total}"

# Create a dictionary with the scraped data
data = {
    'Company Name': [company_name],
    'Industry Group': [industry_group],
    'Country/Region': [country],
    'Identifier': [identifier],
    'Company Description': [company_description],
    'Full Time Employees': [full_time_employees],
    'ESG Risk Rating': [esg_risk_rating],
    'ESG Risk Rating Assessment': [esg_rating_assessment],
    'Industry Group Ranking': [industry_group_ranking_formatted],
    'Universe Ranking': [universe_ranking_formatted]
}

# Create a Pandas DataFrame from the dictionary
df = pd.DataFrame(data)

# Print the DataFrame
df
# Out:
# C:\Users\nayan\AppData\Local\Temp\ipykernel_16076\1385686779.py:30: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   esg_risk_rating = soup.find('h3', text='ESG Risk Rating').find_next('span', class_='').text.strip()
# C:\Users\nayan\AppData\Local\Temp\ipykernel_16076\1385686779.py:34: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   industry_group_ranking = soup.find('p', class_='intro-ranking-heading', text='Industry Group (1st = lowest risk)')
# C:\Users\nayan\AppData\Local\Temp\ipykernel_16076\1385686779.py:40: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   universe_ranking = soup.find('p', class_='intro-ranking-heading', text='Universe')
#   Company Name       Industry Group            Country/Region Identifier
# 0  Apple, Inc.  Technology Hardware  United States of America   NAS:AAPL  \
#
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Configure Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")

def scrape_company_data(stock_symbol):
    # Creating a webdriver instance
    driver = webdriver.Chrome("../chrome_driver/chromedriver.exe",options=chrome_options)
    driver.set_page_load_timeout(10)
    # This instance will be used to log into LinkedIn

    # Opening webpage
    
    driver.get("https://www.sustainalytics.com/esg-rating")
    time.sleep(1)
    

    # waiting for the page to load


    # Searchig for stock symbol 
    tickers = driver.find_element(By.ID, "searchInput")

    # Enter Your Stock Symbol

    for i in stock_symbol:

        tickers.send_keys(i)
        time.sleep(0.5)
    
    time.sleep(2)
    driver.find_element(By.XPATH, "//a[@class='search-link js-fix-path']").click()
    # In case of an error, try changing the
    # XPath used here.

    src = driver.page_source

    # Extract the HTML content
    html_content = src

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the company name
    company_name = soup.find('div', class_='company-name').h2.text.strip()

    # Find the industry group
    industry_group = soup.find('strong', class_='industry-group').text.strip()

    # Find the country/region
    country = soup.find('strong', class_='country').text.strip()

    # Find the identifier
    identifier = soup.find('strong', class_='identifier').text.strip()

    # Find the company description
    company_description = soup.find('div', class_='company-description-text').find('span').text.strip()

    # Find the full-time employees
    full_time_employees = soup.find('div', class_='company-description-details').strong.text.strip()

    # Find the ESG risk rating
    esg_risk_rating = soup.find('h3', text='ESG Risk Rating').find_next('span', class_='').text.strip()
    esg_rating_assessment = soup.find('div', class_='risk-rating-assessment').span.text.strip()

    # Find the industry group ranking
    industry_group_ranking = soup.find('p', class_='intro-ranking-heading', text='Industry Group (1st = lowest risk)')
    industry_group_position = industry_group_ranking.find_next('strong', class_='industry-group-position').text.strip()
    industry_group_positions_total = industry_group_ranking.find_next('span', class_='industry-group-positions-total').text.strip()
    industry_group_ranking_formatted = f"{industry_group_position}/{industry_group_positions_total}"

    # Find the universe ranking
    universe_ranking = soup.find('p', class_='intro-ranking-heading', text='Universe')
    universe_position = universe_ranking.find_next('strong', class_='universe-position').text.strip()
    universe_positions_total = universe_ranking.find_next('span', class_='universe-positions-total').text.strip()
    universe_ranking_formatted = f"{universe_position}/{universe_positions_total}"

    # Create a dictionary with the scraped data
    data = {
        'Company Name': [company_name],
        'Industry Group': [industry_group],
        'Country/Region': [country],
        'Identifier': [identifier],
        'Company Description': [company_description],
        'Full Time Employees': [full_time_employees],
        'ESG Risk Rating': [esg_risk_rating],
        'ESG Risk Rating Assessment': [esg_rating_assessment],
        'Industry Group Ranking': [industry_group_ranking_formatted],
        'Universe Ranking': [universe_ranking_formatted]
    }

    # Create a Pandas DataFrame from the dictionary
    df = pd.DataFrame(data)

    # Return the DataFrame
    return df,data

# %%
df,json=scrape_company_data(stock_symbol='AMZN')
# Out:
# C:\Users\nayan\AppData\Local\Temp\ipykernel_16124\2268496837.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("../chrome_driver/chromedriver.exe",options=chrome_options)
# C:\Users\nayan\AppData\Local\Temp\ipykernel_16124\2268496837.py:67: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   esg_risk_rating = soup.find('h3', text='ESG Risk Rating').find_next('span', class_='').text.strip()
# C:\Users\nayan\AppData\Local\Temp\ipykernel_16124\2268496837.py:71: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   industry_group_ranking = soup.find('p', class_='intro-ranking-heading', text='Industry Group (1st = lowest risk)')
# C:\Users\nayan\AppData\Local\Temp\ipykernel_16124\2268496837.py:77: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
# ...

# %%
json
# Out:
# {'Company Name': ['Amazon.com, Inc.'],
#  'Industry Group': ['Retailing'],
#  'Country/Region': ['United States of America'],
#  'Identifier': ['NAS:AMZN'],
#  'Company Description': ["Amazon is a leading online retailer and one of the highest-grossing e-commerce aggregators, with $386 billion in net sales and approximately $578 billion in estimated physical/digital online gross merchandise volume in 2021. Retail-related revenue represents approximately 80% of the total, followed by Amazon Web Services' cloud computing, storage, database, and other offerings (10%-15%), advertising services (5%), and other. International segments constitute 25%-30% of Amazon's non-AWS sales, led by Germany, the United Kingdom, and Japan."],
#  'Full Time Employees': ['1,541,000'],
#  'ESG Risk Rating': ['Comprehensive'],
#  'ESG Risk Rating Assessment': ['High Risk'],
#  'Industry Group Ranking': ['488/493'],
#  'Universe Ranking': ['10581/15349']}

# %%
df
# Out:
#        Company Name Industry Group            Country/Region Identifier
# 0  Amazon.com, Inc.      Retailing  United States of America   NAS:AMZN  \
#
#                                  Company Description Full Time Employees
# 0  Amazon is a leading online retailer and one of...           1,541,000  \
#
#   ESG Risk Rating ESG Risk Rating Assessment Industry Group Ranking
# 0   Comprehensive                  High Risk                488/493  \
#
#   Universe Ranking
# 0      10581/15349

# %%
import requests
import pandas as pd
from textblob import TextBlob

def get_news_dataframe(api_key, stock_symbol):
    url = f"https://newsapi.org/v2/everything?q={stock_symbol}&apiKey={api_key}"

    try:
        response = requests.get(url)
        data = response.json()

        # Check if the API call was successful
        if response.status_code == 200:
            articles = data["articles"]

            # Create an empty list to store the news data
            news_list = []

            # Iterate over the articles and perform sentiment analysis
            for article in articles:
                title = article["title"]
                source = article["source"]["name"]
                published_date = article["publishedAt"]
                url = article["url"]

                # Perform sentiment analysis on the article title
                blob = TextBlob(title)
                sentiment = blob.sentiment.polarity

                # Append the article data to the list
                news_list.append({
                    "Title": title,
                    "Source": source,
                    "Published Date": published_date,
                    "URL": url,
                    "Sentiment": sentiment
                })

            # Create a DataFrame from the list of dictionaries
            news_df = pd.DataFrame(news_list)

            return news_df

        else:
            print(f"Error: {data['message']}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# Set your API key and stock symbol
api_key = "212e34fad4074c8cb491adc643451684"
stock_symbol = "AAPL"  # Replace with your desired stock symbol

# Call the function to get the news DataFrame
news_dataframe = get_news_dataframe(api_key, stock_symbol)

# Print the DataFrame
news_dataframe
# Out:
#                                                 Title               Source
# 0   Inside one of the strangest looking NASA test ...     Business Insider  \
# 1   'Another masterpiece performance': Apple earni...     Business Insider
# 2   9to5Mac Daily: May 5, 2023 – AAPL earnings, th...              9to5Mac
# 3   AAPL Q2 2023 earnings expected to be down, but...              9to5Mac
# 4   What to Expect From Apple's Earnings Results F...            MacRumors
# ..                                                ...                  ...
# 95  Apple Just Upped Its Dividend: What You Should...          Motley Fool
# 96  Here's How Warren Buffett Is Set to Rake in Ne...          Motley Fool
# 97                   Apple Stock: Buy, Sell, or Hold?          Motley Fool
# 98  Index Funds Are For 'Basic' Investors, Buy The...               Forbes
# 99        Buyers Swarmed These 3 Stocks Post-Earnings  Yahoo Entertainment
#
# ...

# %%
import requests
import pandas as pd
from textblob import TextBlob
import newspaper


def get_indepth_news(url):
    
    article = newspaper.Article(url)  # Limit retries to 1
    article.download()
    article.parse()
    content = article.text
    return content


def get_news_dataframe(api_key, stock_symbol):
    url = f"https://newsapi.org/v2/everything?q={stock_symbol}&apiKey={api_key}"

    try:
        response = requests.get(url)
        data = response.json()

        # Check if the API call was successful
        if response.status_code == 200:
            articles = data["articles"]

            # Create an empty list to store the news data
            news_list = []

            # Iterate over the articles and perform sentiment analysis
            for article in articles:
                title = article["title"]
                source = article["source"]["name"]
                published_date = article["publishedAt"]
                url = article["url"]

                # Get the detailed news content
                try:
                    content = get_indepth_news(url)
                except newspaper.ArticleException as e:
                    print(f"Error fetching article: {e}")
                    content = title


                # Perform sentiment analysis on the article content
                # blob = TextBlob(content)
                # sentiment = blob.sentiment.polarity

                # Append the article data to the list
                news_list.append({
                    "Title": title,
                    "Source": source,
                    "Published Date": published_date,
                    "URL": url,
                    "Content": content,
                })

            # Create a DataFrame from the list of dictionaries
            news_df = pd.DataFrame(news_list)

            return news_df

        else:
            print(f"Error: {data['message']}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# Set your API key and stock symbol
api_key = "212e34fad4074c8cb491adc643451684"
stock_symbol = "AAPL"  # Replace with your desired stock symbol

# Call the function to get the news DataFrame
news_dataframe = get_news_dataframe(api_key, stock_symbol)

# Print the DataFrame
news_dataframe
# Out:
# Error fetching article: Article `download()` failed with HTTPSConnectionPool(host='www.fool.com', port=443): Read timed out. (read timeout=7) on URL https://www.fool.com/investing/2023/05/09/stocks-soar-earnings-buy-apple-vertiv-sunnova/
# Error fetching article: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/bill_stone/2023/05/16/berkshire-hathaways-first-quarter-2023-portfolio-moves/ on URL https://www.forbes.com/sites/bill_stone/2023/05/16/berkshire-hathaways-first-quarter-2023-portfolio-moves/
# Error fetching article: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/michaelfoster/2023/05/20/index-funds-are-for-basic-investors-buy-these-7-payers-instead/ on URL https://www.forbes.com/sites/michaelfoster/2023/05/20/index-funds-are-for-basic-investors-buy-these-7-payers-instead/
# ...

# %% [markdown]
# # latest segment

# %%
import requests
import pandas as pd
import newspaper

def get_indepth_news(url):
    article = newspaper.Article(url)
    article.download()
    article.parse()
    content = article.text
    return content

def get_news_dataframe(api_key, stock_symbol):
    url = f"https://newsapi.org/v2/everything?q={stock_symbol}&apiKey={api_key}"

    try:
        response = requests.get(url)
        data = response.json()

        # Check if the API call was successful
        if response.status_code == 200:
            articles = data["articles"]

            # Create an empty list to store the news data
            news_list = []

            # Define relevant keywords
            keywords = [
    "Stock market",
    stock_symbol,
    "Financial markets",
    "Investing",
    "Stocks",
    "Company earnings",
    "Market trends",
    "Economic indicators",
    "Stock analysis",
    "Corporate news",
    "Market performance",
    "Stock prices",
    "Market volatility",
    "Market outlook",
    "Industry updates",
    "Market movers"
]  # Add more relevant keywords here

            # Iterate over the articles and filter relevant news
            for article in articles:
                title = article["title"]
                source = article["source"]["name"]
                published_date = article["publishedAt"]
                url = article["url"]

                # Get the detailed news content
                try:
                    content = get_indepth_news(url)
                except newspaper.ArticleException as e:
                    print(f"Error fetching article: {e}")
                    content = title

                # Check if any keyword is present in the title or content
                if any(keyword.lower() in title.lower() or keyword.lower() in content.lower() for keyword in keywords):
                    news_list.append({
                        "Title": title,
                        "Source": source,
                        "Published Date": published_date,
                        "URL": url,
                        "Content": content,
                    })

            # Create a DataFrame from the list of dictionaries
            news_df = pd.DataFrame(news_list)

            return news_df

        else:
            print(f"Error: {data['message']}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# Set your API key and stock symbol
api_key = "212e34fad4074c8cb491adc643451684"
stock_symbol = "AAPL"  # Replace with your desired stock symbol

# Call the function to get the news DataFrame
news_dataframe = get_news_dataframe(api_key, stock_symbol)

# Print the DataFrame
news_dataframe
# Out:
# Error fetching article: Article `download()` failed with HTTPSConnectionPool(host='biztoc.com', port=443): Read timed out. (read timeout=7) on URL https://biztoc.com/x/7dd5747b08d8cf73
# Error fetching article: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/bill_stone/2023/05/16/berkshire-hathaways-first-quarter-2023-portfolio-moves/ on URL https://www.forbes.com/sites/bill_stone/2023/05/16/berkshire-hathaways-first-quarter-2023-portfolio-moves/
# Error fetching article: Article `download()` failed with 429 Client Error: Too Many Requests for url: https://macdailynews.com/2023/05/11/what-apples-cash-problem-means-for-aapl-investors/ on URL https://macdailynews.com/2023/05/11/what-apples-cash-problem-means-for-aapl-investors/
# ...

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

import matplotlib.pyplot as plt

def sentiment_analysis(df):
        df = df
        print(f'Shape of collected data is {df.shape}')
        #Sentiment Analysis
        def percentage(part,whole):
            return 100 * float(part)/float(whole)

        #Assigning Initial Values
        positive = 0
        negative = 0
        neutral = 0
        #Creating empty lists
        news_list = []
        neutral_list = []
        negative_list = []
        positive_list = []

        #Iterating over the tweets in the dataframe
        for news in df['Content']:
            news_list.append(news)
            analyzer = SentimentIntensityAnalyzer().polarity_scores(news)
            neg = analyzer['neg']
            neu = analyzer['neu']
            pos = analyzer['pos']
            comp = analyzer['compound']

            if neg > pos:
                negative_list.append(news) #appending the news that satisfies this condition
                negative += 1 #increasing the count by 1
            elif pos > neg:
                positive_list.append(news) #appending the news that satisfies this condition
                positive += 1 #increasing the count by 1
            elif pos == neg:
                neutral_list.append(news) #appending the news that satisfies this condition
                neutral += 1 #increasing the count by 1 

        positive = percentage(positive, len(df)) #percentage is the function defined above
        negative = percentage(negative, len(df))
        neutral = percentage(neutral, len(df))
        
        if positive>negative:
            global_polarity = 1
            tw_pol = 'Overall Positive'
        else:
            tw_pol = 'Overall_Negative'
            global_polarity = 0

        # Converting lists to pandas dataframe
        # news_list = pd.DataFrame(news_list)
        # neutral_list = pd.DataFrame(neutral_list)
        # negative_list = pd.DataFrame(negative_list)
        # positive_list = pd.DataFrame(positive_list)
        # using len(length) function for counting
        print("Positive Sentiment:", '%.2f' % len(positive_list), end='\n')
        print("Neutral Sentiment:", '%.2f' % len(neutral_list), end='\n')
        print("Negative Sentiment:", '%.2f' % len(negative_list), end='\n')

        #Creating PieCart
        labels = ['Positive ['+str(round(positive))+'%]' , 'Neutral ['+str(round(neutral))+'%]','Negative ['+str(round(negative))+'%]']
        sizes = [positive, neutral, negative]
        colors = ['yellowgreen', 'blue','red']
        patches, texts = plt.pie(sizes,colors=colors, startangle=90)
        plt.style.use('default')
        plt.legend(labels)
        plt.title("Sentiment Analysis Result for stock= "+"" )
        plt.axis('equal')
        # plt.savefig('SentAnalysis.png')
        plt.close()
        
        return news_list, global_polarity, tw_pol, positive, neutral, negative, positive_list, negative_list, neutral_list

# %%
news_list, global_polarity, tw_pol, positive, neutral, negative, positive_list, negative_list, neutral_list=sentiment_analysis(df=news_dataframe)
# Out:
# Shape of collected data is (88, 5)
# Positive Sentiment: 79.00
# Neutral Sentiment: 5.00
# Negative Sentiment: 4.00

# %%
neutral_list
# Out:
# ['Apple Q2 23 Earnings $AAPL',
# ...

# %%
import requests
import pandas as pd
import newspaper
from datetime import datetime, timedelta

def get_indepth_news(url):
    article = newspaper.Article(url)
    article.download()
    article.parse()
    content = article.text
    return content

def get_news_dataframe(api_key, stock_symbol):
    # Calculate the date 5 days ago from today
    date_5_days_ago = (datetime.now() - timedelta(days=5)).strftime("%Y-%m-%d")

    url = f"https://newsapi.org/v2/everything?q={stock_symbol}&from={date_5_days_ago}&apiKey={api_key}"

    try:
        response = requests.get(url)
        data = response.json()

        # Check if the API call was successful
        if response.status_code == 200:
            articles = data["articles"]

            # Create an empty list to store the news data
            news_list = []

            # Define relevant keywords
            keywords = [
                "Stock market",
                stock_symbol,
                "Financial markets",
                "Investing",
                "Stocks",
                "Company earnings",
                "Market trends",
                "Economic indicators",
                "Stock analysis",
                "Corporate news",
                "Market performance",
                "Stock prices",
                "Market volatility",
                "Market outlook",
                "Industry updates",
                "Market movers"
            ]  # Add more relevant keywords here

            # Iterate over the articles and filter relevant news
            for article in articles:
                title = article["title"]
                source = article["source"]["name"]
                published_date = article["publishedAt"]
                url = article["url"]

                # Get the detailed news content
                try:
                    content = get_indepth_news(url)
                except newspaper.ArticleException as e:
                    print(f"Error fetching article: {e}")
                    content = title

                # Check if any keyword is present in the title or content
                if any(keyword.lower() in title.lower() or keyword.lower() in content.lower() for keyword in keywords):
                    news_list.append({
                        "Title": title,
                        "Source": source,
                        "Published Date": published_date,
                        "URL": url,
                        "Content": content,
                    })

            # Create a DataFrame from the list of dictionaries
            news_df = pd.DataFrame(news_list)

            return news_df

        else:
            print(f"Error: {data['message']}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# Set your API key and stock symbol
api_key = "212e34fad4074c8cb491adc643451684"
stock_symbol = "AAPL"  # Replace with your desired stock symbol

# Call the function to get the news DataFrame
news_dataframe = get_news_dataframe(api_key, stock_symbol)

# Print the DataFrame
news_dataframe
# Out:
# Error fetching article: Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/sites/greatspeculations/2023/05/23/dont-count-on-apples-new-headset-to-move-the-needle-for-the-stock/ on URL https://www.forbes.com/sites/greatspeculations/2023/05/23/dont-count-on-apples-new-headset-to-move-the-needle-for-the-stock/
# Error fetching article: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.investors.com/research/options/apple-stock-butterfly-spread-benefits-from-neutral-price-action-can-return-925/ on URL https://www.investors.com/research/options/apple-stock-butterfly-spread-benefits-from-neutral-price-action-can-return-925/
# ...

# %%
import openai

# Set up OpenAI API credentials
openai.api_key = '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'

# Define stock symbols to generate tweets for
stock_symbols = ['AAPL', 'GOOGL', 'MSFT']

# Generate and print tweets for each stock symbol
for symbol in stock_symbols:
    prompt = f"Generate a tweet about {symbol}"
    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt=prompt,
        max_tokens=50,
        n=2,
        stop=None,
        temperature=0.7
    )
    print(f'Tweets for {symbol}:')
    for choice in response.choices:
        tweet = choice.text.strip()
        print(f'- {tweet}')
    print()
# Out:
# Tweets for AAPL:
# - Apple just released their quarterly earnings report and it looks amazing! $AAPL is up and running strong 📈 #AAPL #AppleEarnings
# - AAPL is a great stock to invest in! Investing in this tech giant can be a great way to build your portfolio and make some money 💰 #AAPL #investing
#
# Tweets for GOOGL:
# - Check out the latest news from GOOGL - it's paving the way for the future of tech innovation! #GOOGL #TechRevolution
# - A great way to stay up to date on the latest news and trends in tech? Keep an eye on GOOGL! #GOOGL #Tech
#
# Tweets for MSFT:
# - Microsoft continues to innovate and lead the way in technology! #MSFT #technology #innovation
# - Microsoft continues to innovate and lead the way in the tech industry. Stay tuned for more exciting developments from MSFT! #Microsoft #MSFT

# %%
import pandas as pd
import openai

def generate_tweets(stock_symbols, openai_api_key):
    # Set up OpenAI API credentials
    openai.api_key = openai_api_key

    # Initialize an empty list to store the tweets
    tweet_list = []

    # Generate tweets for each stock symbol and add them to the list
    
    prompt = f"Generate a tweet about {stock_symbols}"
    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt=prompt,
        max_tokens=50,
        n=5,
        stop=None,
        temperature=0.7
    )
    tweets = [choice.text.strip() for choice in response.choices]
    for tweet in tweets:
        tweet_list.append({'Stock Symbol': symbol, 'Tweet': tweet})

    # Create a DataFrame from the list of tweets
    df = pd.DataFrame(tweet_list)

    return df

# %%
stock_symbols = 'GOOGL'
openai_api_key = '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'

result_df = generate_tweets(stock_symbols=stock_symbol,openai_api_key=openai_api_key)

print(result_df)
# Out:
#   Stock Symbol                                              Tweet
# 0         MSFT  AAPL just released their new iPhone 12, and it...
# 1         MSFT  AAPL stock is up and running, and the future l...
# 2         MSFT  AAPL is dominating the tech world with their i...
# 3         MSFT  Love AAPL? Keep an eye out for their latest pr...
# 4         MSFT  Apple just announced their newest product, and...
